# %% [markdown]
# <a href="https://colab.research.google.com/github/arthurmraesdsilva-lgtm/codespaces-express/blob/main/GraphQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "graphene>=3.0"
# Out:
# Collecting graphene>=3.0
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene>=3.0)
#   Downloading graphql_core-3.2.8-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene>=3.0)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from graphene>=3.0) (2.9.0.post0)
# Requirement already satisfied: typing-extensions<5,>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from graphene>=3.0) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3,>=2.7.0->graphene>=3.0) (1.17.0)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 6.6 MB/s eta 0:00:00
# Downloading graphql_core-3.2.8-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 12.0 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Installing collected packages: graphql-core, graphql-relay, graphene
# Successfully installed graphene-3.4.3 graphql-core-3.2.8 graphql-relay-3.2.0

# %%
import graphene

# Modelo de produto
class Produto(graphene.ObjectType):
    id = graphene.Int()
    nome = graphene.String()
    preco = graphene.Float()


# Lista inicial de produtos
# Aqui estamos simulando um banco de dados
produtos = [
    {"id": 1, "nome": "Camiseta", "preco": 50.00},
    {"id": 2, "nome": "Tênis", "preco": 120.00}
]


# Consultas GraphQL
class Query(graphene.ObjectType):
    produto = graphene.Field(Produto, id=graphene.Int(required=True))
    produtos = graphene.List(Produto)

    # Buscar um produto pelo ID
    def resolve_produto(root, info, id):
        return next((p for p in produtos if p["id"] == id), None)

    # Buscar todos os produtos
    def resolve_produtos(root, info):
        return produtos


# Mutation para adicionar produto
class AdicionarProduto(graphene.Mutation):

    class Arguments:
        nome = graphene.String(required=True)
        preco = graphene.Float(required=True)

    produto = graphene.Field(Produto)

    def mutate(root, info, nome, preco):
        novo_produto = {
            "id": len(produtos) + 1,
            "nome": nome,
            "preco": preco
        }

        produtos.append(novo_produto)

        return AdicionarProduto(produto=novo_produto)


# Classe principal de mutations
class Mutation(graphene.ObjectType):
    adicionar_produto = AdicionarProduto.Field()


# Criação do schema GraphQL
schema = graphene.Schema(query=Query, mutation=Mutation)

print("Schema GraphQL criado com sucesso!")
# Out:
# Schema GraphQL criado com sucesso!
